# %%
import sys
from pathlib import Path
proj_root = Path('..').resolve()   # ajusta si tu notebook está en otro subdirectorio
sys.path.insert(0, str(proj_root))
from src.utils.canonicalization import read_fasta_into_records_dict

# %%
downstream = read_fasta_into_records_dict("../data/nucleotide_transformer/enhancers/enhancers_train.fasta")

# %%
downstream_seq = downstream["seq_0_1"]

# %%
import mappy as mp

aligner = mp.Aligner("../data/hg38/ncbi_dataset/data/GCF_000001405.26/GCF_000001405.26_GRCh38_genomic.fna", preset="sr")

# %%
hits = list(aligner.map(str(downstream_seq)))

# %%
aligner.dump_index("./test")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 aligner.dump_index("./test")
#
# AttributeError: 'mappy.Aligner' object has no attribute 'dump_index'

# %%
aligner = mp.Aligner("../test.mmi")

# %%
hits = list(aligner.map(str(downstream_seq)))

# %%
print(hits[0].is_primary)
# Out:
# True

# %%
print(dir(hits[0]))
# Out:
# ['MD', 'NM', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'blen', 'cigar', 'cigar_str', 'cs', 'ctg', 'ctg_len', 'ds', 'is_primary', 'mapq', 'mlen', 'q_en', 'q_st', 'r_en', 'r_st', 'read_num', 'strand', 'trans_strand']

# %%
print(hits[0].r_en)
# Out:
# 46339783
